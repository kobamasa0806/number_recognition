# %%
import torch
import torch.nn as nn
import torch.nn.functional as f
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
class MyNet(nn.Module):
    def __init__(self):
        super(MyNet,self).__init__()
        self.conv1 = nn.Conv2d(1,32,3,1)
        self.conv2 = nn.Conv2d(32,64,3,1)
        self.pool = nn.MaxPool2d(2,2)
        self.dropout1 = nn.Dropout2d(0.25)
        self.dropout2 = nn.Dropout2d(0.5)
        self.fc1 = nn.Linear(12*12*64,128)
        self.fc2 = nn.Linear(128,10)

    def forward(self,x):
        x = self.conv1(x)
        x = f.relu(x)
        x = self.conv2(x)
        x = f.relu(x)
        x = self.pool(x)
        x = self.dropout1(x)
        x = x.view(-1,12*12*64)
        x = self.fc1(x)
        x = f.relu(x)
        x = self.dropout2(x)
        x = self.fc2(x)

        return f.log_softmax(x, dim=1)

# %%
from torchsummary import summary
model = MyNet()
print(model)
print(summary(model, (1, 28, 28)))
# Out:
# MyNet(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout2d(p=0.25, inplace=False)
#   (dropout2): Dropout2d(p=0.5, inplace=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             320
#             Conv2d-2           [-1, 64, 24, 24]          18,496
#          MaxPool2d-3           [-1, 64, 12, 12]               0
#          Dropout2d-4           [-1, 64, 12, 12]               0
#             Linear-5                  [-1, 128]       1,179,776
#          Dropout2d-6                  [-1, 128]               0
#             Linear-7                   [-1, 10]           1,290
# ================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.59
# Params size (MB): 4.58
# Estimated Total Size (MB): 5.17
# ----------------------------------------------------------------
# None
# C:\Users\kobamasa\Documents\ai_app\Lib\site-packages\torch\nn\functional.py:1538: UserWarning: dropout2d: Received a 2-D input to dropout2d, which is deprecated and will result in an error in a future release. To retain the behavior and silence this warning, please use dropout instead. Note that dropout2d exists to provide channel-wise dropout on inputs with 2 spatial dimensions, a channel dimension, and an optional batch dimension (i.e. 3D or 4D inputs).
#   warnings.warn(warn_msg)

# %%
def load_MNIST(batch=128):
    transform_augment = transforms.Compose([
        transforms.RandomAffine(degrees=10, scale=(0.9, 1.1)),  # -10~10度の回転、縮小/拡大
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])
    transform_normal = transforms.Compose([transforms.ToTensor(),
                                   transforms.Normalize((0.1307,), (0.3081,))])

    train_set = torchvision.datasets.MNIST(root="./data",
                                           train=True,
                                           download=True,
                                           transform=transform_augment)
    train_loader = torch.utils.data.DataLoader(train_set,
                                               batch_size=batch,
                                               shuffle=True,
                                               num_workers=2)

    val_set = torchvision.datasets.MNIST(root="./data",
                                         train=False,
                                         download=True,
                                         transform=transform_normal)
    val_loader =torch.utils.data.DataLoader(val_set,
                                            batch_size=batch,
                                            shuffle=True,
                                            num_workers=2)

    return {"train":train_loader, "validation":val_loader}

# %%
#エポック数，バッジサイズ
epoch = 20
batch_size = 64
    
#学習結果の保存
history = {
    "train_loss": [],
    "validation_loss": [],
    "validation_acc": []
}

#データのロード
data_loder = load_MNIST(batch=batch_size)

# %%
#GPUが使えるときは使う
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
#ネットワーク構造の構築
net = MyNet().to(device)
print(net)

#最適化方法の設定
optimizer = torch.optim.Adam(params=net.parameters(), lr=0.001)
# Out:
# cpu
# MyNet(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout2d(p=0.25, inplace=False)
#   (dropout2): Dropout2d(p=0.5, inplace=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
for e in range(epoch):
    """ 学習部分 """
    loss = None
    train_loss = 0.0
    net.train() #学習モード
    print("\nTrain start")
    for i,(data,target) in enumerate(data_loder["train"]):
        data,target = data.to(device),target.to(device)

        #勾配の初期化
        optimizer.zero_grad()
        #順伝搬 -> 逆伝搬 -> 最適化
        output = net(data)
        loss = f.nll_loss(output,target)
        train_loss += loss.item()
        loss.backward()
        optimizer.step()

        if i % 100 == 99:
            print("Training: {} epoch. {} iteration. Loss:{}".format(e+1,i+1,loss.item()))

    train_loss /= len(data_loder["train"])
    print("Training loss (ave.): {}".format(train_loss))
    history["train_loss"].append(train_loss)

    """検証部分"""
    print("\nValidation start")
    net.eval() #検証モード(Validation)
    val_loss = 0.0
    accuracy = 0.0

    with torch.no_grad():
        for data,target in data_loder["validation"]:
            data,target = data.to(device),target.to(device)
            
            #順伝搬の計算
            output = net(data)
            loss = f.nll_loss(output,target).item()
            val_loss += f.nll_loss(output,target,reduction='sum').item()
            predict = output.argmax(dim=1,keepdim=True)
            accuracy += predict.eq(target.view_as(predict)).sum().item()

    val_loss /= len(data_loder["validation"].dataset)
    accuracy /= len(data_loder["validation"].dataset)

    print("Validation loss: {}, Accuracy: {}\n".format(val_loss,accuracy))
    history["validation_loss"].append(val_loss)
    history["validation_acc"].append(accuracy)
# Out:
# Train start
# Training: 1 epoch. 100 iteration. Loss:0.337466835975647
# Training: 1 epoch. 200 iteration. Loss:0.1221233680844307
# Training: 1 epoch. 300 iteration. Loss:0.13707391917705536
# Training: 1 epoch. 400 iteration. Loss:0.2359859049320221
# Training: 1 epoch. 500 iteration. Loss:0.028558634221553802
# Training: 1 epoch. 600 iteration. Loss:0.11066557466983795
# Training: 1 epoch. 700 iteration. Loss:0.21513158082962036
# Training: 1 epoch. 800 iteration. Loss:0.20851734280586243
# Training: 1 epoch. 900 iteration. Loss:0.03200065344572067
# Training loss (ave.): 0.23240663336693193
#
# Validation start
# Validation loss: 0.04625987489745021, Accuracy: 0.9863
#
#
# Train start
# Training: 2 epoch. 100 iteration. Loss:0.11343172192573547
# Training: 2 epoch. 200 iteration. Loss:0.047033317387104034
# Training: 2 epoch. 300 iteration. Loss:0.09662520885467529
# Training: 2 epoch. 400 iteration. Loss:0.14664004743099213
# Training: 2 epoch. 500 iteration. Loss:0.04240863397717476
# Training: 2 epoch. 600 iteration. Loss:0.23764842748641968
# Training: 2 epoch. 700 iteration. Loss:0.04752169921994209
# Training: 2 epoch. 800 iteration. Loss:0.09886482357978821
# Training: 2 epoch. 900 iteration. Loss:0.029638640582561493
# Training loss (ave.): 0.11059513846998101
#
# Validation start
# Validation loss: 0.04007557681053877, Accuracy: 0.9869
#
#
# Train start
# Training: 3 epoch. 100 iteration. Loss:0.1880989372730255
# Training: 3 epoch. 200 iteration. Loss:0.028088288381695747
# Training: 3 epoch. 300 iteration. Loss:0.03322726488113403
# Training: 3 epoch. 400 iteration. Loss:0.1622309386730194
# Training: 3 epoch. 500 iteration. Loss:0.08147041499614716
# Training: 3 epoch. 600 iteration. Loss:0.012506045401096344
# Training: 3 epoch. 700 iteration. Loss:0.1089509055018425
# Training: 3 epoch. 800 iteration. Loss:0.1531013548374176
# Training: 3 epoch. 900 iteration. Loss:0.11138852685689926
# Training loss (ave.): 0.09001429732898866
#
# Validation start
# Validation loss: 0.031094308828562497, Accuracy: 0.9893
#
#
# Train start
# Training: 4 epoch. 100 iteration. Loss:0.05819906294345856
# Training: 4 epoch. 200 iteration. Loss:0.15786193311214447
# Training: 4 epoch. 300 iteration. Loss:0.011885779909789562
# Training: 4 epoch. 400 iteration. Loss:0.0340462327003479
# Training: 4 epoch. 500 iteration. Loss:0.0596296600997448
# Training: 4 epoch. 600 iteration. Loss:0.15376925468444824
# Training: 4 epoch. 700 iteration. Loss:0.08074136078357697
# Training: 4 epoch. 800 iteration. Loss:0.0056900628842413425
# Training: 4 epoch. 900 iteration. Loss:0.027899619191884995
# Training loss (ave.): 0.07941392637657196
#
# Validation start
# Validation loss: 0.02555924685774371, Accuracy: 0.9921
#
#
# Train start
# Training: 5 epoch. 100 iteration. Loss:0.04723997414112091
# Training: 5 epoch. 200 iteration. Loss:0.3027936816215515
# Training: 5 epoch. 300 iteration. Loss:0.03704911842942238
# Training: 5 epoch. 400 iteration. Loss:0.04334346577525139
# Training: 5 epoch. 500 iteration. Loss:0.08674968034029007
# Training: 5 epoch. 600 iteration. Loss:0.04986826330423355
# Training: 5 epoch. 700 iteration. Loss:0.036806654185056686
# Training: 5 epoch. 800 iteration. Loss:0.17142130434513092
# Training: 5 epoch. 900 iteration. Loss:0.04119240865111351
# Training loss (ave.): 0.07231598893584593
#
# Validation start
# Validation loss: 0.026310440273582935, Accuracy: 0.9917
#
#
# Train start
# Training: 6 epoch. 100 iteration. Loss:0.01765006221830845
# Training: 6 epoch. 200 iteration. Loss:0.0871293917298317
# Training: 6 epoch. 300 iteration. Loss:0.16359665989875793
# Training: 6 epoch. 400 iteration. Loss:0.033467281609773636
# Training: 6 epoch. 500 iteration. Loss:0.04338378086686134
# Training: 6 epoch. 600 iteration. Loss:0.028974318876862526
# Training: 6 epoch. 700 iteration. Loss:0.14890798926353455
# Training: 6 epoch. 800 iteration. Loss:0.16721685230731964
# Training: 6 epoch. 900 iteration. Loss:0.03398791328072548
# Training loss (ave.): 0.06896914095495707
#
# Validation start
# Validation loss: 0.026226021403446792, Accuracy: 0.9919
#
#
# Train start
# Training: 7 epoch. 100 iteration. Loss:0.019525635987520218
# Training: 7 epoch. 200 iteration. Loss:0.03005925938487053
# Training: 7 epoch. 300 iteration. Loss:0.0060113295912742615
# Training: 7 epoch. 400 iteration. Loss:0.019867250695824623
# Training: 7 epoch. 500 iteration. Loss:0.06385629624128342
# Training: 7 epoch. 600 iteration. Loss:0.12600557506084442
# Training: 7 epoch. 700 iteration. Loss:0.036867689341306686
# Training: 7 epoch. 800 iteration. Loss:0.09883122146129608
# Training: 7 epoch. 900 iteration. Loss:0.09145113080739975
# Training loss (ave.): 0.06334157646634926
#
# Validation start
# Validation loss: 0.025869498094171287, Accuracy: 0.9916
#
#
# Train start
# Training: 8 epoch. 100 iteration. Loss:0.042123593389987946
# Training: 8 epoch. 200 iteration. Loss:0.13419075310230255
# Training: 8 epoch. 300 iteration. Loss:0.07352624833583832
# Training: 8 epoch. 400 iteration. Loss:0.034953679889440536
# Training: 8 epoch. 500 iteration. Loss:0.23893269896507263
# Training: 8 epoch. 600 iteration. Loss:0.025521881878376007
# Training: 8 epoch. 700 iteration. Loss:0.02192213572561741
# Training: 8 epoch. 800 iteration. Loss:0.11304113268852234
# Training: 8 epoch. 900 iteration. Loss:0.013139095157384872
# Training loss (ave.): 0.057822530713908596
#
# Validation start
# Validation loss: 0.02525558173264144, Accuracy: 0.9925
#
#
# Train start
# Training: 9 epoch. 100 iteration. Loss:0.1354539543390274
# Training: 9 epoch. 200 iteration. Loss:0.005085218697786331
# Training: 9 epoch. 300 iteration. Loss:0.017970966175198555
# Training: 9 epoch. 400 iteration. Loss:0.008641384541988373
# Training: 9 epoch. 500 iteration. Loss:0.04018715023994446
# Training: 9 epoch. 600 iteration. Loss:0.028686920180916786
# Training: 9 epoch. 700 iteration. Loss:0.04525298252701759
# Training: 9 epoch. 800 iteration. Loss:0.02861560508608818
# Training: 9 epoch. 900 iteration. Loss:0.040743350982666016
# Training loss (ave.): 0.05735705044916841
#
# Validation start
# Validation loss: 0.022661192942433992, Accuracy: 0.9931
#
#
# Train start
# Training: 10 epoch. 100 iteration. Loss:0.02854539081454277
# Training: 10 epoch. 200 iteration. Loss:0.026814956218004227
# Training: 10 epoch. 300 iteration. Loss:0.027132637798786163
# Training: 10 epoch. 400 iteration. Loss:0.017670074477791786
# Training: 10 epoch. 500 iteration. Loss:0.06557421386241913
# Training: 10 epoch. 600 iteration. Loss:0.026367545127868652
# Training: 10 epoch. 700 iteration. Loss:0.16646890342235565
# Training: 10 epoch. 800 iteration. Loss:0.010439829900860786
# Training: 10 epoch. 900 iteration. Loss:0.011781007051467896
# Training loss (ave.): 0.05343899811304776
#
# Validation start
# Validation loss: 0.022773627614026192, Accuracy: 0.9928
#
#
# Train start
# Training: 11 epoch. 100 iteration. Loss:0.03548385202884674
# Training: 11 epoch. 200 iteration. Loss:0.038577839732170105
# Training: 11 epoch. 300 iteration. Loss:0.07748337835073471
# Training: 11 epoch. 400 iteration. Loss:0.08915050327777863
# Training: 11 epoch. 500 iteration. Loss:0.03384261950850487
# Training: 11 epoch. 600 iteration. Loss:0.06611597537994385
# Training: 11 epoch. 700 iteration. Loss:0.040047045797109604
# Training: 11 epoch. 800 iteration. Loss:0.04951447248458862
# Training: 11 epoch. 900 iteration. Loss:0.0020761836785823107
# Training loss (ave.): 0.050651354445707376
#
# Validation start
# Validation loss: 0.022268093398399653, Accuracy: 0.994
#
#
# Train start
# Training: 12 epoch. 100 iteration. Loss:0.037203967571258545
# Training: 12 epoch. 200 iteration. Loss:0.01683298870921135
# Training: 12 epoch. 300 iteration. Loss:0.016308508813381195
# Training: 12 epoch. 400 iteration. Loss:0.10109843313694
# Training: 12 epoch. 500 iteration. Loss:0.03243354707956314
# Training: 12 epoch. 600 iteration. Loss:0.042040929198265076
# Training: 12 epoch. 700 iteration. Loss:0.051183197647333145
# Training: 12 epoch. 800 iteration. Loss:0.04663895443081856
# Training: 12 epoch. 900 iteration. Loss:0.09937308728694916
# Training loss (ave.): 0.04980329645691869
#
# Validation start
# Validation loss: 0.025171354161808268, Accuracy: 0.9936
#
#
# Train start
# Training: 13 epoch. 100 iteration. Loss:0.04175211489200592
# Training: 13 epoch. 200 iteration. Loss:0.010556746274232864
# Training: 13 epoch. 300 iteration. Loss:0.015386136248707771
# Training: 13 epoch. 400 iteration. Loss:0.006360646802932024
# Training: 13 epoch. 500 iteration. Loss:0.091375432908535
# Training: 13 epoch. 600 iteration. Loss:0.08099475502967834
# Training: 13 epoch. 700 iteration. Loss:0.003134215483441949
# Training: 13 epoch. 800 iteration. Loss:0.005518261343240738
# Training: 13 epoch. 900 iteration. Loss:0.0030895450618118048
# Training loss (ave.): 0.046945188429391785
#
# Validation start
# Validation loss: 0.01860398599850014, Accuracy: 0.9946
#
#
# Train start
# Training: 14 epoch. 100 iteration. Loss:0.025338362902402878
# Training: 14 epoch. 200 iteration. Loss:0.06214242801070213
# Training: 14 epoch. 300 iteration. Loss:0.04407714307308197
# Training: 14 epoch. 400 iteration. Loss:0.015894358977675438
# Training: 14 epoch. 500 iteration. Loss:0.008283200673758984
# Training: 14 epoch. 600 iteration. Loss:0.013505017384886742
# Training: 14 epoch. 700 iteration. Loss:0.01910783350467682
# Training: 14 epoch. 800 iteration. Loss:0.004218565300107002
# Training: 14 epoch. 900 iteration. Loss:0.09915769845247269
# Training loss (ave.): 0.04399733319693033
#
# Validation start
# Validation loss: 0.02020557478719129, Accuracy: 0.9941
#
#
# Train start
# Training: 15 epoch. 100 iteration. Loss:0.009315820410847664
# Training: 15 epoch. 200 iteration. Loss:0.037430841475725174
# Training: 15 epoch. 300 iteration. Loss:0.0024547032080590725
# Training: 15 epoch. 400 iteration. Loss:0.040243759751319885
# Training: 15 epoch. 500 iteration. Loss:0.011709790676832199
# Training: 15 epoch. 600 iteration. Loss:0.049342554062604904
# Training: 15 epoch. 700 iteration. Loss:0.010481134988367558
# Training: 15 epoch. 800 iteration. Loss:0.021743280813097954
# Training: 15 epoch. 900 iteration. Loss:0.04339531064033508
# Training loss (ave.): 0.04452253986449256
#
# Validation start
# Validation loss: 0.020267523367377, Accuracy: 0.9941
#
#
# Train start
# Training: 16 epoch. 100 iteration. Loss:0.06722855567932129
# Training: 16 epoch. 200 iteration. Loss:0.1180838868021965
# Training: 16 epoch. 300 iteration. Loss:0.019957587122917175
# Training: 16 epoch. 400 iteration. Loss:0.010307992808520794
# Training: 16 epoch. 500 iteration. Loss:0.01283886656165123
# Training: 16 epoch. 600 iteration. Loss:0.011172139085829258
# Training: 16 epoch. 700 iteration. Loss:0.056016385555267334
# Training: 16 epoch. 800 iteration. Loss:0.04753807559609413
# Training: 16 epoch. 900 iteration. Loss:0.06116088852286339
# Training loss (ave.): 0.04426120623179437
#
# Validation start
# Validation loss: 0.024515471457703098, Accuracy: 0.9929
#
#
# Train start
# Training: 17 epoch. 100 iteration. Loss:0.007800019811838865
# Training: 17 epoch. 200 iteration. Loss:0.02079252526164055
# Training: 17 epoch. 300 iteration. Loss:0.07392926514148712
# Training: 17 epoch. 400 iteration. Loss:0.026956863701343536
# Training: 17 epoch. 500 iteration. Loss:0.02608589082956314
# Training: 17 epoch. 600 iteration. Loss:0.10022663325071335
# Training: 17 epoch. 700 iteration. Loss:0.12303336709737778
# Training: 17 epoch. 800 iteration. Loss:0.015145569108426571
# Training: 17 epoch. 900 iteration. Loss:0.04662559926509857
# Training loss (ave.): 0.04225515415808851
#
# Validation start
# Validation loss: 0.021185155654809204, Accuracy: 0.9937
#
#
# Train start
# Training: 18 epoch. 100 iteration. Loss:0.0009917172137647867
# Training: 18 epoch. 200 iteration. Loss:0.004049543756991625
# Training: 18 epoch. 300 iteration. Loss:0.040313877165317535
# Training: 18 epoch. 400 iteration. Loss:0.002631732728332281
# Training: 18 epoch. 500 iteration. Loss:0.0034854193218052387
# Training: 18 epoch. 600 iteration. Loss:0.010484532453119755
# Training: 18 epoch. 700 iteration. Loss:0.060820821672677994
# Training: 18 epoch. 800 iteration. Loss:0.02386443316936493
# Training: 18 epoch. 900 iteration. Loss:0.055675774812698364
# Training loss (ave.): 0.03893976738968832
#
# Validation start
# Validation loss: 0.019970197783305776, Accuracy: 0.9942
#
#
# Train start
# Training: 19 epoch. 100 iteration. Loss:0.05374607443809509
# Training: 19 epoch. 200 iteration. Loss:0.041848074644804
# Training: 19 epoch. 300 iteration. Loss:0.02104039490222931
# Training: 19 epoch. 400 iteration. Loss:0.005314916372299194
# Training: 19 epoch. 500 iteration. Loss:0.05617181211709976
# Training: 19 epoch. 600 iteration. Loss:0.01273855660110712
# Training: 19 epoch. 700 iteration. Loss:0.03317635878920555
# Training: 19 epoch. 800 iteration. Loss:0.014377282001078129
# Training: 19 epoch. 900 iteration. Loss:0.007674857974052429
# Training loss (ave.): 0.0388210920040741
#
# Validation start
# Validation loss: 0.021090935552911833, Accuracy: 0.9943
#
#
# Train start
# Training: 20 epoch. 100 iteration. Loss:0.046304959803819656
# Training: 20 epoch. 200 iteration. Loss:0.08467435836791992
# Training: 20 epoch. 300 iteration. Loss:0.1263817846775055
# Training: 20 epoch. 400 iteration. Loss:0.008337895385921001
# Training: 20 epoch. 500 iteration. Loss:0.00619462039321661
# Training: 20 epoch. 600 iteration. Loss:0.08251183480024338
# Training: 20 epoch. 700 iteration. Loss:0.05853089690208435
# Training: 20 epoch. 800 iteration. Loss:0.006558968685567379
# Training: 20 epoch. 900 iteration. Loss:0.07484718412160873
# Training loss (ave.): 0.03879178577549641
#
# Validation start
# Validation loss: 0.021381862617010482, Accuracy: 0.9943

# %%
plt.figure()
plt.plot(range(1, epoch+1), history["train_loss"], label="train_loss")
plt.plot(range(1, epoch+1), history["validation_loss"], label="validation_loss")
plt.xlabel("epoch")
plt.legend()
plt.savefig("loss.png")

plt.figure()
plt.plot(range(1, epoch+1), history["validation_acc"])
plt.title("test accuracy")
plt.xlabel("epoch")
plt.savefig("test_acc.png")

# %%
plt.figure()
plt.plot(range(1, epoch+1), history["train_loss"], label="train_loss")
plt.plot(range(1, epoch+1), history["validation_loss"], label="validation_loss")
plt.xlabel("epoch")
plt.legend()
plt.savefig("loss_02.png")

plt.figure()
plt.plot(range(1, epoch+1), history["validation_acc"])
plt.title("test accuracy")
plt.xlabel("epoch")
plt.savefig("test_acc_02.png")

# %%
PATH = "./model/model_cnn_ver02.pt"
torch.save(net.state_dict(), PATH)
